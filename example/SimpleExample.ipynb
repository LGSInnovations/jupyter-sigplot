# %%
from jupyter_sigplot.sigplot import Plot

# %%
plot = Plot()
plot.overlay_array([3, 2, 1])
# Out:
# Plot(uuid='3f43c346-c58f-4de9-84b1-915db6feff8f')
# <img alt="SigPlot plot" src="data:image/png;base64,..." width="100%">

# %%
plot = Plot(xi=True)
plot.overlay_array([1, 2, 3])
# Out:
# Plot(plot_options={'xi': True}, uuid='21e98eec-0df1-4d23-9029-5a515f8f8c47')
# <img alt="SigPlot plot" src="data:image/png;base64,..." width="100%">
